# %% [markdown]
# #### Energy Performance Certificate (EPC) Data pulled from https://statistics.gov.scot/data/domestic-energy-performance-certificates
# Filename: D_EPC_data_2012-2022Q3.zip <br>
# Total Size: 379MB<br>
# Made up of a .csv file for every quarter.  Each row in a .csv file contains a single EPC report for a domestic dwelling (non-commercial) in Scotland by property address<br>
# <br><br>
# #### Postal Code and GIS Data pulled from https://download.geonames.org/export/zip
# Filename: GB_Full.csv.zip<br>
# Total Size: 14MB<br>
# Contains a single tab delimeted .txt file with GIS lat/lon and City/Town name per postal code.  File has no column names.  Columns are in order as follows:<br>
#
# country code      : iso country code, 2 characters<br>
# postal code       : varchar(20)<br>
# place name        : varchar(180)<br>
# admin name1       : 1. order subdivision (state) varchar(100)<br>
# admin code1       : 1. order subdivision (state) varchar(20)<br>
# admin name2       : 2. order subdivision (county/province) varchar(100)<br>
# admin code2       : 2. order subdivision (county/province) varchar(20)<br>
# admin name3       : 3. order subdivision (community) varchar(100)<br>
# admin code3       : 3. order subdivision (community) varchar(20)<br>
# latitude          : estimated latitude (wgs84)<br>
# longitude         : estimated longitude (wgs84)<br>
# accuracy          : accuracy of lat/lng from 1=estimated, 4=geonameid, 6=centroid of addresses or shape<br>

# %%
import pandas as pd
import random as rn
from os import listdir
from os.path import isfile, join
pd.pandas.set_option('display.max_columns', None)

# %% [markdown]
# ### Load Data Files

# %% [markdown]
# ##### Energy Performance Certificates

# %%
# get all csv files as a list
cwd = os.getcwd()
csvfiles = [f for f in listdir(cwd) if (isfile(join(cwd, f))& ('.csv' in f))]

# %%
try:
    csvfiles.remove('Scotland_EPC.csv')
except:
    pass
csvfiles.remove('ukpostcodes.csv')
csvfiles.remove('Grade_Scaffold.csv')
csvfiles
# Out:
# ['2012Q1.csv',
#  '2012Q2.csv',
#  '2012Q3.csv',
#  '2012Q4.csv',
#  '2013Q1.csv',
#  '2013Q2.csv',
#  '2013Q3.csv',
#  '2013Q4.csv',
#  '2014Q1.csv',
#  '2014Q2.csv',
#  '2014Q3.csv',
#  '2014Q4.csv',
#  '2015Q1.csv',
#  '2015Q2.csv',
#  '2015Q3.csv',
#  '2015Q4.csv',
#  '2016Q1.csv',
#  '2016Q2.csv',
#  '2016Q3.csv',
#  '2016Q4.csv',
#  '2017Q1.csv',
#  '2017Q2.csv',
#  '2017Q3.csv',
#  '2017Q4.csv',
#  '2018Q1.csv',
#  '2018Q2.csv',
#  '2018Q3.csv',
#  '2018Q4.csv',
#  '2019Q1.csv',
#  '2019Q2.csv',
#  '2019Q3.csv',
#  '2019Q4.csv',
#  '2020Q1.csv',
#  '2020Q2.csv',
#  '2020Q3.csv',
#  '2020Q4.csv',
#  '2021Q1.csv',
#  '2021Q2.csv',
#  '2021Q3.csv',
#  '2021Q4.csv',
#  '2022Q1.csv',
#  '2022Q2.csv',
#  '2022Q3.csv']

# %%
df_epc_reports_in = pd.DataFrame()
for file in csvfiles:
    df_temp = pd.read_csv(file, low_memory=False)
    print (file)
    df_epc_reports_in = pd.concat([df_epc_reports_in, df_temp])
# Out:
# 2012Q1.csv
# 2012Q2.csv
# 2012Q3.csv
# 2012Q4.csv
# 2013Q1.csv
# 2013Q2.csv
# 2013Q3.csv
# 2013Q4.csv
# 2014Q1.csv
# 2014Q2.csv
# 2014Q3.csv
# 2014Q4.csv
# 2015Q1.csv
# 2015Q2.csv
# 2015Q3.csv
# 2015Q4.csv
# 2016Q1.csv
# 2016Q2.csv
# 2016Q3.csv
# 2016Q4.csv
# 2017Q1.csv
# 2017Q2.csv
# 2017Q3.csv
# 2017Q4.csv
# 2018Q1.csv
# 2018Q2.csv
# 2018Q3.csv
# 2018Q4.csv
# 2019Q1.csv
# 2019Q2.csv
# 2019Q3.csv
# 2019Q4.csv
# 2020Q1.csv
# 2020Q2.csv
# 2020Q3.csv
# 2020Q4.csv
# 2021Q1.csv
# 2021Q2.csv
# 2021Q3.csv
# 2021Q4.csv
# 2022Q1.csv
# 2022Q2.csv
# 2022Q3.csv

# %%
df_epc_reports_in.shape
# Out:
# (1596414, 104)

# %%
df_epc_reports_in.head(2)
# Out:
#    Property_UPRN     OSG_UPRN             ADDRESS1      ADDRESS2   POST_TOWN  \
# 0     1000005786  133031562.0  23 ASHGROVE SQUARE            NaN      ELGIN
# 1     1000005962  906074808.0              FLAT 4   1 DEAN PATH   EDINBURGH
#
#    Postcode Date of Assessment      Type of Assessment Date of Certificate  \
# 0  IV30 1UN         2012-02-02  SAP, existing dwelling          2012-02-02
# 1   EH4 3BG         2012-03-13  SAP, existing dwelling          2012-03-15
#
#    Primary Energy Indicator (kWh/m²/year)  Total floor area (m²)  \
# 0                                   338.0                     61
# 1                                   532.0                     60
#
#    Total current energy costs over 3 years (£)  \
# 0                                       1581.0
# 1                                       3576.0
#
#    Potential future savings over 3 years (£)  \
# 0                                       51.0
# 1                                       84.0
#
#    Current energy efficiency rating Current energy efficiency rating band  \
# 0                                71                                     C
# 1                                33                                     F
#
#    Potential Energy Efficiency Rating Potential energy efficiency rating band  \
# 0                                  72                                       C
# 1                                  35                                       F
#
#    Current Environmental Impact Rating  \
# 0                                   54
# 1                                   32
#
#   Current Environmental Impact Rating Band  \
# 0                                        E
# 1                                        F
#
#    Potential Environmental Impact Rating  \
# 0                                     54
# 1                                     33
#
#   Potential Environmental Impact Rating Band  \
# 0                                          E
# 1                                          F
#
#    CO2 Emissions Current Per Floor Area (kg.CO2/m²/yr)  \
# 0                                               60.0
# 1                                              103.0
#
#                                         Improvements  \
# 0  Description: Low energy lighting for all fixed...
# 1  Description: Internal or external wall insulat...
#
#                                     WALL_DESCRIPTION WALL_ENERGY_EFF  \
# 0  Timber frame, as built, insulated (assumed) | ...    Good | Good
# 1  Sandstone, as built, insulated (assumed) | San...    Good | Good
#
#    WALL_ENV_EFF                                   ROOF_DESCRIPTION  \
# 0  Good | Good   (another dwelling above) | (another dwelling a...
# 1  Good | Good   (another dwelling above) | (another dwelling a...
#
#   ROOF_ENERGY_EFF ROOF_ENV_EFF  \
# 0      N/A | N/A    N/A | N/A
# 1      N/A | N/A    N/A | N/A
#
#                                    FLOOR_DESCRIPTION FLOOR_ENERGY_EFF  \
# 0  Suspended, limited insulation (assumed) | Susp...       N/A | N/A
# 1   (other premises below) | (other premises below)        N/A | N/A
#
#   FLOOR_ENV_EFF                WINDOWS_DESCRIPTION WINDOWS_ENERGY_EFF  \
# 0    N/A | N/A   Description: Fully double glazed               Good
# 1    N/A | N/A         Description: Single glazed          Very Poor
#
#   WINDOWS_ENV_EFF                               MAINHEAT_DESCRIPTION  \
# 0           Good   Electric storage heaters | Electric storage he...
# 1      Very Poor   Boiler and radiators, mains gas | Boiler and r...
#
#   MAINHEAT_ENERGY_EFF        MAINHEAT_ENV_EFF  \
# 0  Average | Average   Very Poor | Very Poor
# 1        Good | Good             Good | Good
#
#                             MAINHEATCONT_DESCRIPTION MAINHEATC_ENERGY_EFF  \
# 0     Manual charge control | Manual charge control          Poor | Poor
# 1  Programmer and room thermostat | Programmer an...   Average | Average
#
#     MAINHEATC_ENV_EFF                            SECONDHEAT_DESCRIPTION  \
# 0        Poor | Poor   Room heaters, electric | Room heaters, electric
# 1  Average | Average                                       None | None
#
#   SHEATING_ENERGY_EFF SHEATING_ENV_EFF  \
# 0          N/A | N/A        N/A | N/A
# 1          N/A | N/A        N/A | N/A
#
#                                 HOTWATER_DESCRIPTION HOT_WATER_ENERGY_EFF  \
# 0  Electric immersion, off-peak | Electric immers...   Average | Average
# 1               From main system | From main system          Good | Good
#
#         HOT_WATER_ENV_EFF                               LIGHTING_DESCRIPTION  \
# 0  Very Poor | Very Poor   Low energy lighting in 43% of fixed outlets | ...
# 1            Good | Good   Low energy lighting in 14% of fixed outlets | ...
#
#   LIGHTING_ENERGY_EFF    LIGHTING_ENV_EFF AIR_TIGHTNESS_DESCRIPTION  \
# 0  Average | Average   Average | Average                        NaN
# 1        Poor | Poor         Poor | Poor                        NaN
#
#   AIR_TIGHTNESS_ENERGY_EFF AIR_TIGHTNESS_ENV_EFF  \
# 0                      NaN                   NaN
# 1                      NaN                   NaN
#
#    Current Emissions (T.CO2/yr)  Potential Reduction in Emissions (T.CO2/yr)  \
# 0                           3.7                                          0.1
# 1                           6.2                                          0.1
#
#    Current heating costs over 3 years (£)  \
# 0                                  1050.0
# 1                                  3048.0
#
#    Potential heating costs over 3 years (£)  \
# 0                                    1068.0
# 1                                    3060.0
#
#    Current hot water costs over 3 years (£)  \
# 0                                     339.0
# 1                                     321.0
#
#    Potential hot water costs over 3 years (£)  \
# 0                                       339.0
# 1                                       321.0
#
#    Current lighting costs over 3 years (£)  \
# 0                                    192.0
# 1                                    207.0
#
#    Potential lighting costs over 3 years (£) Alternative Measures 2  \
# 0                                      123.0                    NaN
# 1                                      111.0                    NaN
#
#   LZC Energy Source  Space Heating  Water Heating  Impact Of Loft Insulation  \
# 0               NaN         5515.0         1844.0                          0
# 1               NaN        22082.0         2337.0                          0
#
#    Impact Of Cavity Wall Insulation  Impact Of Solid Wall Insulation  \
# 0                                 0                                0
# 1                                 0                                0
#
#    Addendum Text Part 1 Construction Age Band  Part 1 Floor 0 Room Height  \
# 0            NaN                    1992-1998                        2.38
# 1            NaN                    1984-1991                        2.60
#
#                                     Data Zone  Energy Consumption Potential  \
# 0                      S01004295 (IZ Sixteen)                         334.0
# 1  S01002133 (Dean, West End and West Coates)                         522.0
#
#    Extensions Count  Fixed Lighting Outlets Count  \
# 0                 0                             7
# 1                 0                            14
#
#    Low Energy Lighting Outlets Count  Low Energy Lighting %    Flat Level  \
# 0                                  3                   43.0  ground floor
# 1                                  2                   14.0     mid floor
#
#   Flat Location  Glazed Area  Habitable Room Count Heat Loss Corridor  \
# 0            00            1                     3        no corridor
# 1            01            1                     3  unheated corridor
#
#    Heated Room Count Local Authority Main Gas  \
# 0                  3           Moray        N
# 1                  3  Edinburgh City        Y
#
#                        Main Heating 1 Category Main Heating 1 Fuel Type  \
# 0                     electric storage heaters                      NaN
# 1  boiler with radiators or underfloor heating                      NaN
#
#    Main Heating 1 Control Mechanical Ventilation Meter Type  \
# 0                    2401                natural       dual
# 1                    2104                natural     Single
#
#    Multiple Glazed Proportion                          Multiple Glazing Type  \
# 0                         100  double glazing installed during or after 2002
# 1                           0                                    not defined
#
#    Open Fireplaces Count        Photovoltaic Supply Solar Water Heating  \
# 0                      0  Array: Roof Area: 0%;  |                    N
# 1                      0  Array: Roof Area: 0%;  |                    N
#
#              Tenure Transaction Type  Unheated Corridor Length Ward Code  \
# 0    owner-occupied    marketed sale                       NaN    00QXMF
# 1  rented (private)           rental                      2.88    00QPME
#
#           Ward Name  Wind Turbines Count   Built Form Property Type  \
# 0  Elgin City North                    0  End-Terrace          Flat
# 1        Inverleith                    0          NaN          Flat
#
#                                       Data Zone 2011
# 0  S01011105 (Elgin Cathedral to Ashgrove and Pin...
# 1                     S01008869 (Deans Village - 02)

# %% [markdown]
# ##### GIS Data by Postal Code

# %%
column_names = ['Country Code','postcode','Location','admin name1','admin code1','admin name2','admin code2','admin name3','admin code3','latitude','longitude','accuracy']
df_postal_codes = pd.read_csv('GB_full.txt', sep='\t', names=column_names)
df_postal_codes.shape
# Out:
# C:\Users\davej\AppData\Local\Temp\ipykernel_38668\814810470.py:2: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_postal_codes = pd.read_csv('GB_full.txt', sep='\t', names=column_names)
# (1797499, 12)

# %%
df_postal_codes = df_postal_codes[df_postal_codes['admin name1']=='Scotland'].copy()
df_postal_codes.head(2)
# Out:
#         Country Code  postcode     Location admin name1 admin code1  \
# 1544963           GB  AB43 1AD  Fraserburgh    Scotland         SCT
# 1544964           GB   DD2 5AA  Invergowrie    Scotland         SCT
#
#                admin name2 admin code2 admin name3 admin code3  latitude  \
# 1544963      Aberdeenshire         NaN         NaN         NaN   57.6573
# 1544964  Perth and Kinross         NaN         NaN   S12000048   56.4608
#
#          longitude  accuracy
# 1544963    -2.0443         6
# 1544964    -3.0583         6

# %%
df_postal_codes.drop(['Country Code','admin code1','admin name2','admin code2','admin name3','admin code3','accuracy'], axis=1, inplace=True, errors='ignore')
df_postal_codes.rename({'admin name1':'Country'},axis=1, inplace=True)
df_postal_codes.head(2)
# Out:
#          postcode     Location   Country  latitude  longitude
# 1544963  AB43 1AD  Fraserburgh  Scotland   57.6573    -2.0443
# 1544964   DD2 5AA  Invergowrie  Scotland   56.4608    -3.0583

# %%
df_postal_codes.groupby('Location').count()
# Out:
#                    postcode  Country  latitude  longitude
# Location
# ABERFELDY                 4        4         4          4
# AIRDRIE                  16       16        16         16
# Abbey Ward              219      219       219        219
# Aberchirder              38       38        38         38
# Aberdeen               5300     5300      5300       5300
# ...                     ...      ...       ...        ...
# Wigtown West Ward       384      384       384        384
# Winchburgh               65       65        65         65
# Windygates               46       46        46         46
# Wishaw                  652      652       652        652
# Wishaw Ward              29       29        29         29
#
# [934 rows x 4 columns]

# %%
df_postal_codes[df_postal_codes['postcode']=='IV26 2UN']
# Out:
#          postcode  Location   Country  latitude  longitude
# 1610123  IV26 2UN  Ullapool  Scotland   57.8982    -5.1549

# %% [markdown]
# #### EPC Report Dataset Prep

# %%
df_epc_reports_in.groupby('Tenure').count()
# Out:
#                   Property_UPRN  OSG_UPRN  ADDRESS1  ADDRESS2  POST_TOWN  \
# Tenure
# owner-occupied           971497    922827    970315    555894     967491
# rented (private)         158906    151579    158490    107503     157831
# rented (social)          372055    364953    372010    212554     370886
# unknown                   93956     57201     93805     50038      93831
#
#                   Postcode  Date of Assessment  Type of Assessment  \
# Tenure
# owner-occupied      971497              971497              971497
# rented (private)    158906              158906              158906
# rented (social)     372055              372055              372055
# unknown              93956               93956               93956
#
#                   Date of Certificate  Primary Energy Indicator (kWh/m²/year)  \
# Tenure
# owner-occupied                 971497                                  971497
# rented (private)               158906                                  158906
# rented (social)                372055                                  372055
# unknown                         93956                                   93956
#
#                   Total floor area (m²)  \
# Tenure
# owner-occupied                   971497
# rented (private)                 158906
# rented (social)                  372055
# unknown                           93956
#
#                   Total current energy costs over 3 years (£)  \
# Tenure
# owner-occupied                                         971497
# rented (private)                                       158906
# rented (social)                                        372055
# unknown                                                 93956
#
#                   Potential future savings over 3 years (£)  \
# Tenure
# owner-occupied                                       971497
# rented (private)                                     158906
# rented (social)                                      372055
# unknown                                               93956
#
#                   Current energy efficiency rating  \
# Tenure
# owner-occupied                              971497
# rented (private)                            158906
# rented (social)                             372055
# unknown                                      93956
#
#                   Current energy efficiency rating band  \
# Tenure
# owner-occupied                                   971497
# rented (private)                                 158906
# rented (social)                                  372055
# unknown                                           93956
#
#                   Potential Energy Efficiency Rating  \
# Tenure
# owner-occupied                                971497
# rented (private)                              158906
# rented (social)                               372055
# unknown                                        93956
#
#                   Potential energy efficiency rating band  \
# Tenure
# owner-occupied                                     971497
# rented (private)                                   158906
# rented (social)                                    372055
# unknown                                             93956
#
#                   Current Environmental Impact Rating  \
# Tenure
# owner-occupied                                 971497
# rented (private)                               158906
# rented (social)                                372055
# unknown                                         93956
#
#                   Current Environmental Impact Rating Band  \
# Tenure
# owner-occupied                                      971497
# rented (private)                                    158906
# rented (social)                                     372055
# unknown                                              93956
#
#                   Potential Environmental Impact Rating  \
# Tenure
# owner-occupied                                   971497
# rented (private)                                 158906
# rented (social)                                  372055
# unknown                                           93956
#
#                   Potential Environmental Impact Rating Band  \
# Tenure
# owner-occupied                                        971497
# rented (private)                                      158906
# rented (social)                                       372055
# unknown                                                93956
#
#                   CO2 Emissions Current Per Floor Area (kg.CO2/m²/yr)  \
# Tenure
# owner-occupied                                               971497
# rented (private)                                             158906
# rented (social)                                              372055
# unknown                                                       93956
#
#                   Improvements  WALL_DESCRIPTION  WALL_ENERGY_EFF  \
# Tenure
# owner-occupied          935447            971497           971497
# rented (private)        150466            158906           158906
# rented (social)         334262            372055           372055
# unknown                  63504             93956            93956
#
#                   WALL_ENV_EFF  ROOF_DESCRIPTION  ROOF_ENERGY_EFF  \
# Tenure
# owner-occupied          971497            971497           950750
# rented (private)        158906            158906           152950
# rented (social)         372055            372055           362780
# unknown                  93956             93956            91426
#
#                   ROOF_ENV_EFF  FLOOR_DESCRIPTION  FLOOR_ENERGY_EFF  \
# Tenure
# owner-occupied          950750             971497            897164
# rented (private)        152950             158906            145713
# rented (social)         362780             372055            348075
# unknown                  91426              93956             91622
#
#                   FLOOR_ENV_EFF  WINDOWS_DESCRIPTION  WINDOWS_ENERGY_EFF  \
# Tenure
# owner-occupied           897164               971497              971497
# rented (private)         145713               158906              158906
# rented (social)          348075               372055              372055
# unknown                   91622                93956               93956
#
#                   WINDOWS_ENV_EFF  MAINHEAT_DESCRIPTION  MAINHEAT_ENERGY_EFF  \
# Tenure
# owner-occupied             971497                971497               971497
# rented (private)           158906                158906               158906
# rented (social)            372055                372055               372055
# unknown                     93956                 93956                93956
#
#                   MAINHEAT_ENV_EFF  MAINHEATCONT_DESCRIPTION  \
# Tenure
# owner-occupied              971497                    971497
# rented (private)            158906                    158906
# rented (social)             372055                    372055
# unknown                      93956                     93956
#
#                   MAINHEATC_ENERGY_EFF  MAINHEATC_ENV_EFF  \
# Tenure
# owner-occupied                  971497             971497
# rented (private)                158906             158906
# rented (social)                 372055             372055
# unknown                          93956              93956
#
#                   SECONDHEAT_DESCRIPTION  SHEATING_ENERGY_EFF  \
# Tenure
# owner-occupied                    971497               881817
# rented (private)                  158906               144646
# rented (social)                   372055               347155
# unknown                            93956                82371
#
#                   SHEATING_ENV_EFF  HOTWATER_DESCRIPTION  \
# Tenure
# owner-occupied              881817                971497
# rented (private)            144646                158906
# rented (social)             347155                372055
# unknown                      82371                 93956
#
#                   HOT_WATER_ENERGY_EFF  HOT_WATER_ENV_EFF  \
# Tenure
# owner-occupied                  971497             971497
# rented (private)                158906             158906
# rented (social)                 372055             372055
# unknown                          93956              93956
#
#                   LIGHTING_DESCRIPTION  LIGHTING_ENERGY_EFF  LIGHTING_ENV_EFF  \
# Tenure
# owner-occupied                  971497               971497            971497
# rented (private)                158906               158906            158906
# rented (social)                 372055               372055            372055
# unknown                          93956                93956             93956
#
#                   AIR_TIGHTNESS_DESCRIPTION  AIR_TIGHTNESS_ENERGY_EFF  \
# Tenure
# owner-occupied                        48894                     48759
# rented (private)                        326                       325
# rented (social)                        6726                      6721
# unknown                               82721                     82511
#
#                   AIR_TIGHTNESS_ENV_EFF  Current Emissions (T.CO2/yr)  \
# Tenure
# owner-occupied                    48759                        971497
# rented (private)                    325                        158906
# rented (social)                    6721                        372055
# unknown                           82511                         93956
#
#                   Potential Reduction in Emissions (T.CO2/yr)  \
# Tenure
# owner-occupied                                         971497
# rented (private)                                       158906
# rented (social)                                        372055
# unknown                                                 93956
#
#                   Current heating costs over 3 years (£)  \
# Tenure
# owner-occupied                                    971497
# rented (private)                                  158906
# rented (social)                                   372055
# unknown                                            93956
#
#                   Potential heating costs over 3 years (£)  \
# Tenure
# owner-occupied                                      971497
# rented (private)                                    158906
# rented (social)                                     372055
# unknown                                              93956
#
#                   Current hot water costs over 3 years (£)  \
# Tenure
# owner-occupied                                      971497
# rented (private)                                    158906
# rented (social)                                     372055
# unknown                                              93956
#
#                   Potential hot water costs over 3 years (£)  \
# Tenure
# owner-occupied                                        971497
# rented (private)                                      158906
# rented (social)                                       372055
# unknown                                                93956
#
#                   Current lighting costs over 3 years (£)  \
# Tenure
# owner-occupied                                     971497
# rented (private)                                   158906
# rented (social)                                    372055
# unknown                                             93956
#
#                   Potential lighting costs over 3 years (£)  \
# Tenure
# owner-occupied                                       971497
# rented (private)                                     158906
# rented (social)                                      372055
# unknown                                               93956
#
#                   Alternative Measures 2  LZC Energy Source  Space Heating  \
# Tenure
# owner-occupied                    449180              84801         971484
# rented (private)                   78532               7511         158897
# rented (social)                   115293              33081         372036
# unknown                             1820              53376          93931
#
#                   Water Heating  Impact Of Loft Insulation  \
# Tenure
# owner-occupied           971488                     971497
# rented (private)         158906                     158906
# rented (social)          372055                     372055
# unknown                   93956                      93956
#
#                   Impact Of Cavity Wall Insulation  \
# Tenure
# owner-occupied                              971497
# rented (private)                            158906
# rented (social)                             372055
# unknown                                      93956
#
#                   Impact Of Solid Wall Insulation  Addendum Text  \
# Tenure
# owner-occupied                             971497              0
# rented (private)                           158906              0
# rented (social)                            372055              0
# unknown                                     93956              0
#
#                   Part 1 Construction Age Band  Part 1 Floor 0 Room Height  \
# Tenure
# owner-occupied                          890633                      964879
# rented (private)                        155929                      158796
# rented (social)                         362851                      369832
# unknown                                  10327                       76594
#
#                   Data Zone  Energy Consumption Potential  Extensions Count  \
# Tenure
# owner-occupied       912076                        971497            971497
# rented (private)     157077                        158906            158906
# rented (social)      364436                        372055            372055
# unknown               34578                         93956             93956
#
#                   Fixed Lighting Outlets Count  \
# Tenure
# owner-occupied                          971497
# rented (private)                        158906
# rented (social)                         372055
# unknown                                  93956
#
#                   Low Energy Lighting Outlets Count  Low Energy Lighting %  \
# Tenure
# owner-occupied                               971497                 971497
# rented (private)                             158906                 158906
# rented (social)                              372055                 372055
# unknown                                       93956                  93956
#
#                   Flat Level  Flat Location  Glazed Area  \
# Tenure
# owner-occupied        328029         317025       971497
# rented (private)      103766         103549       158906
# rented (social)       226168         222146       372055
# unknown                32827           3584        93956
#
#                   Habitable Room Count  Heat Loss Corridor  Heated Room Count  \
# Tenure
# owner-occupied                  971497              317025             971497
# rented (private)                158906              103549             158906
# rented (social)                 372055              222146             372055
# unknown                          93956                3584              93956
#
#                   Local Authority  Main Gas  Main Heating 1 Category  \
# Tenure
# owner-occupied             912076    195038                   971497
# rented (private)           157077     36709                   158906
# rented (social)            364436     74331                   372055
# unknown                     34578      9462                    93956
#
#                   Main Heating 1 Fuel Type  Main Heating 1 Control  \
# Tenure
# owner-occupied                      946476                  971497
# rented (private)                    154210                  158906
# rented (social)                     363010                  372055
# unknown                              81175                   93956
#
#                   Mechanical Ventilation  Meter Type  \
# Tenure
# owner-occupied                    941483      922600
# rented (private)                  158693      158580
# rented (social)                   366132      365313
# unknown                            43052       10404
#
#                   Multiple Glazed Proportion  Multiple Glazing Type  \
# Tenure
# owner-occupied                        971497                 922600
# rented (private)                      158906                 158580
# rented (social)                       372055                 365313
# unknown                                93956                  10404
#
#                   Open Fireplaces Count  Photovoltaic Supply  \
# Tenure
# owner-occupied                   971497               940961
# rented (private)                 158906               158663
# rented (social)                  372055               369145
# unknown                           93956                52030
#
#                   Solar Water Heating  Transaction Type  \
# Tenure
# owner-occupied                 932010            971470
# rented (private)               158592            158877
# rented (social)                365917            371726
# unknown                         18581             93956
#
#                   Unheated Corridor Length  Ward Code  Ward Name  \
# Tenure
# owner-occupied                      204488     912076     912076
# rented (private)                     77445     157077     157077
# rented (social)                     145596     364436     364436
# unknown                               2698      34578      34578
#
#                   Wind Turbines Count  Built Form  Property Type  \
# Tenure
# owner-occupied                 971497      968091         971497
# rented (private)               158906      158349         158906
# rented (social)                372055      370906         372055
# unknown                         93956       87444          93956
#
#                   Data Zone 2011
# Tenure
# owner-occupied            965723
# rented (private)          158640
# rented (social)           369788
# unknown                    80853

# %%
columns_to_keep = ['ADDRESS1','ADDRESS2','POST_TOWN','Postcode', 'Date of Assessment', 'Current energy efficiency rating', 'Main Heating 1 Category', 'Main Heating 1 Fuel Type',
                    'Current energy efficiency rating band','Potential Energy Efficiency Rating','Potential energy efficiency rating band',
                    'Current Environmental Impact Rating','Current Environmental Impact Rating Band','Potential Environmental Impact Rating',
                    'Potential Environmental Impact Rating Band','Property Type','Built Form','Part 1 Construction Age Band']

# %%
df_epc_reports = df_epc_reports_in[columns_to_keep]
df_epc_reports.head()
# Out:
#               ADDRESS1               ADDRESS2   POST_TOWN  Postcode  \
# 0  23 ASHGROVE SQUARE                     NaN      ELGIN   IV30 1UN
# 1              FLAT 4            1 DEAN PATH   EDINBURGH    EH4 3BG
# 2   37 HERITAGE DRIVE                 CARRON     FALKIRK    FK2 8EL
# 3           LANGARRIC   53 ANDERSON CRESCENT     FALKIRK    FK1 2ED
# 4                 3F2      21 GIBSON TERRACE   EDINBURGH   EH11 1AT
#
#   Date of Assessment  Current energy efficiency rating  \
# 0         2012-02-02                                71
# 1         2012-03-13                                33
# 2         2012-03-05                                56
# 3         2012-03-20                                70
# 4         2012-03-04                                63
#
#                        Main Heating 1 Category Main Heating 1 Fuel Type  \
# 0                     electric storage heaters                      NaN
# 1  boiler with radiators or underfloor heating                      NaN
# 2                                 room heaters                      NaN
# 3  boiler with radiators or underfloor heating                      NaN
# 4  boiler with radiators or underfloor heating                      NaN
#
#   Current energy efficiency rating band  Potential Energy Efficiency Rating  \
# 0                                     C                                  72
# 1                                     F                                  35
# 2                                     D                                  57
# 3                                     C                                  72
# 4                                     D                                  63
#
#   Potential energy efficiency rating band  \
# 0                                       C
# 1                                       F
# 2                                       D
# 3                                       C
# 4                                       D
#
#    Current Environmental Impact Rating  \
# 0                                   54
# 1                                   32
# 2                                   59
# 3                                   67
# 4                                   64
#
#   Current Environmental Impact Rating Band  \
# 0                                        E
# 1                                        F
# 2                                        D
# 3                                        D
# 4                                        D
#
#    Potential Environmental Impact Rating  \
# 0                                     54
# 1                                     33
# 2                                     61
# 3                                     68
# 4                                     64
#
#   Potential Environmental Impact Rating Band Property Type   Built Form  \
# 0                                          E          Flat  End-Terrace
# 1                                          F          Flat          NaN
# 2                                          D          Flat  End-Terrace
# 3                                          D         House     Detached
# 4                                          D          Flat  Mid-Terrace
#
#   Part 1 Construction Age Band
# 0                    1992-1998
# 1                    1984-1991
# 2                    1976-1983
# 3                    1999-2002
# 4                  before 1919

# %%
# Filter out all homes that aren't stand_alone buildings
df_epc_reports = df_epc_reports[df_epc_reports['Built Form'].isin(['Detached'])]
df_epc_reports.groupby('Built Form').count()
# Out:
#             ADDRESS1  ADDRESS2  POST_TOWN  Postcode  Date of Assessment  \
# Built Form
# Detached      371314    230544     369724    371735              371735
#
#             Current energy efficiency rating  Main Heating 1 Category  \
# Built Form
# Detached                              371735                   371735
#
#             Main Heating 1 Fuel Type  Current energy efficiency rating band  \
# Built Form
# Detached                      358036                                 371735
#
#             Potential Energy Efficiency Rating  \
# Built Form
# Detached                                371735
#
#             Potential energy efficiency rating band  \
# Built Form
# Detached                                     371735
#
#             Current Environmental Impact Rating  \
# Built Form
# Detached                                 371735
#
#             Current Environmental Impact Rating Band  \
# Built Form
# Detached                                      371735
#
#             Potential Environmental Impact Rating  \
# Built Form
# Detached                                   371735
#
#             Potential Environmental Impact Rating Band  Property Type  \
# Built Form
# Detached                                        371735         371735
#
#             Part 1 Construction Age Band
# Built Form
# Detached                          296695

# %% [markdown]
# ##### Join EPC Data with GIS Data

# %%
# add lat/log coords for each zipcode in Scotland
df_epc_reports = pd.merge(df_epc_reports, df_postal_codes, how='left', left_on='Postcode',right_on='postcode')

# %%
# add Jitter offset to all let and long coords
df_epc_reports['lat_jitter'] = df_epc_reports.apply(lambda row: rn.random(), axis=1)
df_epc_reports['lon_jitter'] = df_epc_reports.apply(lambda row: rn.random(), axis=1)

# %%
# Get outward Postal Code on its own for Mapping purposes
df_epc_reports['Outward Postal Code'] = df_epc_reports.apply(lambda row: row['Postcode'].split()[0], axis=1)

# %%
df_epc_reports.head( 2)
# Out:
#         ADDRESS1               ADDRESS2   POST_TOWN  Postcode  \
# 0     LANGARRIC   53 ANDERSON CRESCENT     FALKIRK    FK1 2ED
# 1  Garden Villa         Kenmore Street   Aberfeldy   PH15 2BL
#
#   Date of Assessment  Current energy efficiency rating  \
# 0         2012-03-20                                70
# 1         2012-03-07                                52
#
#                        Main Heating 1 Category Main Heating 1 Fuel Type  \
# 0  boiler with radiators or underfloor heating                      NaN
# 1  boiler with radiators or underfloor heating                      NaN
#
#   Current energy efficiency rating band  Potential Energy Efficiency Rating  \
# 0                                     C                                  72
# 1                                     E                                  54
#
#   Potential energy efficiency rating band  \
# 0                                       C
# 1                                       E
#
#    Current Environmental Impact Rating  \
# 0                                   67
# 1                                   41
#
#   Current Environmental Impact Rating Band  \
# 0                                        D
# 1                                        E
#
#    Potential Environmental Impact Rating  \
# 0                                     68
# 1                                     42
#
#   Potential Environmental Impact Rating Band Property Type Built Form  \
# 0                                          D         House   Detached
# 1                                          E         House   Detached
#
#   Part 1 Construction Age Band  postcode    Location   Country  latitude  \
# 0                    1999-2002   FK1 2ED  Shieldhill  Scotland   55.9731
# 1                  before 1919  PH15 2BL   Aberfeldy  Scotland   56.6185
#
#    longitude  lat_jitter  lon_jitter Outward Postal Code
# 0    -3.7631    0.008828    0.176403                 FK1
# 1    -3.8705    0.917791    0.229899                PH15

# %% [markdown]
# ### Further Filtering and Field Naming

# %%
df_epc_reports.rename({'Part 1 Construction Age Band':'Year Built'}, axis=1,inplace=True, errors='ignore')
df_epc_reports.shape
# Out:
# (371735, 26)

# %% [markdown]
# Impute "Unknown Date' where the Year Built could not be determined

# %%
df_epc_reports['Year Built']=df_epc_reports['Year Built'].fillna('Unknown Date')
num_rows = df_epc_reports.shape[0]
df_epc_reports.shape
# Out:
# (371735, 26)

# %% [markdown]
# Remove properties where latitude and longitude could not be determined

# %%
df_epc_reports = df_epc_reports[~df_epc_reports['latitude'].isna().copy()]
df_epc_reports = df_epc_reports[~df_epc_reports['longitude'].isna().copy()]
print('Total Rows dropped where location data could not be determined:',num_rows - df_epc_reports.shape[0])
df_epc_reports.shape
# Out:
# Total Rows dropped where location data could not be determined: 3881
# (367854, 26)

# %% [markdown]
# Impute Fuel Type = "No Heating" where Main Heating 1 Category = "none"

# %%
df_epc_reports['Main Heating 1 Fuel Type'] = df_epc_reports.apply(lambda row: 'none' if row['Main Heating 1 Category']=='none' else row['Main Heating 1 Fuel Type'], axis=1)

# %%
df_epc_reports.head()
# Out:
#         ADDRESS1               ADDRESS2    POST_TOWN  Postcode  \
# 0     LANGARRIC   53 ANDERSON CRESCENT      FALKIRK    FK1 2ED
# 1  Garden Villa         Kenmore Street    Aberfeldy   PH15 2BL
# 2     SUNNYVIEW       17 HILLSIDE ROAD     ABERDEEN   AB14 0TX
# 3    FARM HOUSE               BONFIELD   ST ANDREWS   KY16 9RR
# 4  6 Reen Place               Bothwell      Glasgow    G71 8HB
#
#   Date of Assessment  Current energy efficiency rating  \
# 0         2012-03-20                                70
# 1         2012-03-07                                52
# 2         2012-02-01                                68
# 3         2012-03-20                                48
# 4         2012-01-10                                68
#
#                        Main Heating 1 Category Main Heating 1 Fuel Type  \
# 0  boiler with radiators or underfloor heating                      NaN
# 1  boiler with radiators or underfloor heating                      NaN
# 2  boiler with radiators or underfloor heating                      NaN
# 3  boiler with radiators or underfloor heating                      NaN
# 4  boiler with radiators or underfloor heating                      NaN
#
#   Current energy efficiency rating band  Potential Energy Efficiency Rating  \
# 0                                     C                                  72
# 1                                     E                                  54
# 2                                     D                                  70
# 3                                     E                                  52
# 4                                     D                                  71
#
#   Potential energy efficiency rating band  \
# 0                                       C
# 1                                       E
# 2                                       C
# 3                                       E
# 4                                       C
#
#    Current Environmental Impact Rating  \
# 0                                   67
# 1                                   41
# 2                                   66
# 3                                   42
# 4                                   67
#
#   Current Environmental Impact Rating Band  \
# 0                                        D
# 1                                        E
# 2                                        D
# 3                                        E
# 4                                        D
#
#    Potential Environmental Impact Rating  \
# 0                                     68
# 1                                     42
# 2                                     69
# 3                                     45
# 4                                     69
#
#   Potential Environmental Impact Rating Band Property Type Built Form  \
# 0                                          D         House   Detached
# 1                                          E         House   Detached
# 2                                          C         House   Detached
# 3                                          E         House   Detached
# 4                                          C         House   Detached
#
#     Year Built  postcode       Location   Country  latitude  longitude  \
# 0    1999-2002   FK1 2ED     Shieldhill  Scotland   55.9731    -3.7631
# 1  before 1919  PH15 2BL      Aberfeldy  Scotland   56.6185    -3.8705
# 2    1992-1998  AB14 0TX    Peterculter  Scotland   57.0992    -2.2679
# 3  before 1919  KY16 9RR  Strathkinness  Scotland   56.3349    -2.8817
# 4    1992-1998   G71 8HB       Bothwell  Scotland   55.8133    -4.0664
#
#    lat_jitter  lon_jitter Outward Postal Code
# 0    0.008828    0.176403                 FK1
# 1    0.917791    0.229899                PH15
# 2    0.881183    0.733025                AB14
# 3    0.535311    0.941927                KY16
# 4    0.864454    0.840911                 G71

# %%
df_epc_reports.to_csv('Scotland_EPC.csv')
